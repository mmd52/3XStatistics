# %%
import pandas as pd
pd.options.display.max_rows=10
pd.options.display.max_columns=50
import numpy as np
import warnings
warnings.filterwarnings('ignore')
print("=================================== Packages Loaded ===================================")
# Out:
# =================================== Packages Loaded ===================================

# %%
df=pd.read_csv('EnglishData.csv')
del df['Timestamp']
df.columns=['SmartPhoneUsagePeriod','SmartPhoneBrand','MainUsagePhone','UsagePeriod','ReasonForBuying','NumApps',
            'Top5Apps','DesiredFeature','PurchaseFrequency','Brand','Color','CameraQuality','BatteryLife','OS','Price',
            'ValueForMoney','Recom_Frnd_Fly','Trends','PromotionsAvailable','Call/Text','PrefMsgApp','PaymentGatewayUsage',
            'PriceRange','PhoneDistraction','Country','CountryLiveIn','Age']
df=df.drop(df.index[0:8])
print("Shape of data:" + str(df.shape))
df.info()
# Out:
# Shape of data:(110, 27)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110 entries, 8 to 117
# Data columns (total 27 columns):
# SmartPhoneUsagePeriod    110 non-null object
# SmartPhoneBrand          110 non-null object
# MainUsagePhone           110 non-null object
# UsagePeriod              110 non-null object
# ReasonForBuying          110 non-null object
# NumApps                  110 non-null object
# Top5Apps                 110 non-null object
# DesiredFeature           106 non-null object
# PurchaseFrequency        110 non-null object
# Brand                    110 non-null object
# Color                    110 non-null float64
# CameraQuality            110 non-null float64
# BatteryLife              110 non-null float64
# OS                       110 non-null float64
# Price                    110 non-null float64
# ValueForMoney            110 non-null float64
# Recom_Frnd_Fly           110 non-null float64
# Trends                   110 non-null float64
# ...

# %%
df.head()
# Out:
#    SmartPhoneUsagePeriod SmartPhoneBrand        MainUsagePhone UsagePeriod  \
# 8      More than 6 years        Motorola               Texting       Night
# 9      More than 6 years          Iphone  Surfing the internet     Morning
# 10   Between 4 - 6 years          Iphone       Taking pictures   Afternoon
# 11     More than 6 years          Iphone               Texting       Night
# 12     Less than 2 years          Iphone          Social media   Afternoon
#
#            ReasonForBuying  NumApps  \
# 8   Features and functions  11 - 35
# 9   Features and functions  11 - 35
# 10  Features and functions   1 - 10
# 11  Features and functions  36 - 60
# 12  Features and functions   1 - 10
#
#                                              Top5Apps  \
# 8   WhatsApp, Appy Geek , Yahoo mail , Instagram, ...
# 9          WhatsApp, safari, photo, Spotify, YouTube
# 10  (Instagram) (Facebook) (Spotify) (WhatsApp) (A...
# 11             Facebook, Amazon, Waze, Tinder, Grindr
# ...

# %%
# Fix country Column Live in
df['CountryLiveIn'].loc[df['CountryLiveIn']=='United States']='USA'
df['CountryLiveIn'].loc[df['CountryLiveIn']=='United States ']='USA'
df['CountryLiveIn'].loc[df['CountryLiveIn']=='United States']='USA'
df['CountryLiveIn'].loc[df['CountryLiveIn']=='United States of America']='USA'
df['CountryLiveIn'].loc[df['CountryLiveIn']=='U.S']='USA'
df['CountryLiveIn'].loc[df['CountryLiveIn']=='USA ']='USA'
df['CountryLiveIn'].loc[df['CountryLiveIn']=='usa']='USA'
df['CountryLiveIn'].loc[df['CountryLiveIn']=='usa ']='USA'

df['CountryLiveIn'].loc[df['CountryLiveIn']=='Italy ']='Italy'
df['CountryLiveIn'].loc[df['CountryLiveIn']=='italy']='Italy'
df['CountryLiveIn'].loc[df['CountryLiveIn']=='Italia']='Italy'
df['CountryLiveIn'].loc[df['CountryLiveIn']=='ITALIA']='Italy'

df['CountryLiveIn'].loc[df['CountryLiveIn']=='Brasil']='Brazil'
df['CountryLiveIn'].loc[df['CountryLiveIn']=='Brasil ']='Brazil'
df['CountryLiveIn'].loc[df['CountryLiveIn']=='Belo Horizonte ']='Brazil'

df['CountryLiveIn'].loc[df['CountryLiveIn']=='India ']='India'
df['CountryLiveIn'].loc[df['CountryLiveIn']=='INDIA']='India'

df['CountryLiveIn'].loc[df['CountryLiveIn']=='APARTADO ANTIOQUIA']='Colombia'

# Fix country Column
df['Country'].loc[df['Country']=='INDIA']='India'
df['Country'].loc[df['Country']=='India ']='India'

df['Country'].loc[df['Country']=='United States of America']='USA'
df['Country'].loc[df['Country']=='United States']='USA'

df['Country'].loc[df['Country']=='Brasil']='Brazil'
df['Country'].loc[df['Country']=='Brasil ']='Brazil'

df['Country'].loc[df['Country']=='Italy ']='Italy'
df['Country'].loc[df['Country']=='Italia']='Italy'
df['Country'].loc[df['Country']=='italy']='Italy'


df['Country'].loc[df['Country']=='COLOMBIA']='Colombia'
df['Country'].loc[df['Country']=='Colombia ']='Colombia'
df['Country'].loc[df['Country']=='BOGOTA - COLOMBIA']='Colombia'

# %%
df.head()
# Out:
#    SmartPhoneUsagePeriod SmartPhoneBrand        MainUsagePhone UsagePeriod  \
# 8      More than 6 years        Motorola               Texting       Night
# 9      More than 6 years          Iphone  Surfing the internet     Morning
# 10   Between 4 - 6 years          Iphone       Taking pictures   Afternoon
# 11     More than 6 years          Iphone               Texting       Night
# 12     Less than 2 years          Iphone          Social media   Afternoon
#
#            ReasonForBuying  NumApps  \
# 8   Features and functions  11 - 35
# 9   Features and functions  11 - 35
# 10  Features and functions   1 - 10
# 11  Features and functions  36 - 60
# 12  Features and functions   1 - 10
#
#                                              Top5Apps  \
# 8   WhatsApp, Appy Geek , Yahoo mail , Instagram, ...
# 9          WhatsApp, safari, photo, Spotify, YouTube
# 10  (Instagram) (Facebook) (Spotify) (WhatsApp) (A...
# 11             Facebook, Amazon, Waze, Tinder, Grindr
# ...

# %%
df['Top5Apps']=df['Top5Apps'].str.replace('\) \(',',')
df['Top5Apps']=df['Top5Apps'].str.replace('\.\ ',',')
df['Top5Apps']=df['Top5Apps'].str.replace('-\ ',',')
AppsDf=df['Top5Apps'].str.split(',',expand=True)
AppsDf.columns=['Top1App','Top2App','Top3App','Top4App','Top5App','Top6App','Top7App']
del AppsDf['Top6App']
del AppsDf['Top7App']

FinalDF=pd.concat([df, AppsDf], axis=1)
del FinalDF['Top5Apps']

# %%
FinalDF.head()
# Out:
#    SmartPhoneUsagePeriod SmartPhoneBrand        MainUsagePhone UsagePeriod  \
# 8      More than 6 years        Motorola               Texting       Night
# 9      More than 6 years          Iphone  Surfing the internet     Morning
# 10   Between 4 - 6 years          Iphone       Taking pictures   Afternoon
# 11     More than 6 years          Iphone               Texting       Night
# 12     Less than 2 years          Iphone          Social media   Afternoon
#
#            ReasonForBuying  NumApps  \
# 8   Features and functions  11 - 35
# 9   Features and functions  11 - 35
# 10  Features and functions   1 - 10
# 11  Features and functions  36 - 60
# 12  Features and functions   1 - 10
#
#                                        DesiredFeature PurchaseFrequency Brand  \
# 8                                  Battery efficiency       1 - 2 years     1
# 9                                                USB        1 - 2 years    10
# ...

# %%
FinalDF['Top1App'].loc[FinalDF['Top1App']=='Whatsaap']='WhatsApp'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='Whatsapp ']='WhatsApp'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='wats up']='WhatsApp'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='whatsapp']='WhatsApp'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='watsapp ']='WhatsApp'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='Whats app']='WhatsApp'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='whats app']='WhatsApp'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='whatapp']='WhatsApp'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='What\'s up']='WhatsApp'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='Watsapp']='WhatsApp'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='What\'s app']='WhatsApp'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='Whatsup']='WhatsApp'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='Whatsup ']='WhatsApp'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='facebook']='Facebook'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='Facebook ']='Facebook'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='Fb']='Facebook'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='Messenger ']='FBMessenger'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='Messenger']='FBMessenger'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='Facebook Messenger']='FBMessenger'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='Google maps']='GMaps'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='Snap Chat']='SnapChat'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='Money control']='MoneyControl'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='(Instagram']='Instagram'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='Gmail']='GMail'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='Safari mail whatsapp ']='Safari'
FinalDF['Top1App'].loc[FinalDF['Top1App']=='Whatsapp instagram Facebook waze Itaú ']='WhatsApp'

###################################################################################################

FinalDF['Top2App'].loc[FinalDF['Top2App']==' Instagram']='Instagram'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Instagram ']='Instagram'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' instagram']='Instagram'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' facebook']='Facebook'
FinalDF['Top2App'].loc[FinalDF['Top2App']=='facebook']='Facebook'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' facebook ']='Facebook'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Facebook']='Facebook'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Facebook ']='Facebook'
FinalDF['Top2App'].loc[FinalDF['Top2App']=='Whatsapp']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' WhatsApp']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Whatsaap']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Whatsapp ']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' wats up']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' whatsapp']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' whatsapp ']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' watsapp ']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']=='  whatsapp']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Whats app']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' whats app']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' whatapp']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' What\'s up']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' what\’s up ']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Watsapp']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' What\'s app']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Whatsup']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Whatsup ']='WhatsApp'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' safari']='Safari'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Samsung pay']='SamsungPay'
FinalDF['Top2App'].loc[FinalDF['Top2App']=='G mail']='GMail'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Gmail']='GMail'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' gmail']='GMail'
FinalDF['Top2App'].loc[FinalDF['Top2App']=='gmail']='GMail'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Google Maps']='GMaps'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' google maps']='GMaps'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' gmaps']='GMaps'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' maps ']='GMaps'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' LinkedIn']='LinkedIn'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Prime videos']='AmazonPrime'
FinalDF['Top2App'].loc[FinalDF['Top2App']=='AmazonPrime ']='AmazonPrime'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Messenger']='FBMessenger'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' messenger']='FBMessenger'
FinalDF['Top2App'].loc[FinalDF['Top2App']=='  YouTube']='YouTube'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' YouTube ']='YouTube'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Simple Radio']='Radio'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Waze']='Waze'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' photo']='Gallery'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Amazon']='Amazon'
FinalDF['Top2App'].loc[FinalDF['Top2App']=='linkedin']='linkedIn'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Twitter']='Twitter'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' google duo']='Duo'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Viber']='Viber'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Splitwise']='Splitwise'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' traductor']='Traductor'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Chrome']='Chrome'
FinalDF['Top2App'].loc[FinalDF['Top2App']==' Flipboard']='Flipboard'

###################################################################################################

FinalDF['Top3App'].loc[FinalDF['Top3App']==' Instagram']='Instagram'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' istagram']='Instagram'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='instagram']='Instagram'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Instagram ']='Instagram'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' instagram']='Instagram'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' facebook']='Facebook'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='facebook']='Facebook'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' facebook ']='Facebook'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Facebook']='Facebook'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='  facebook']='Facebook'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Facebook ']='Facebook'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='facebook ']='Facebook'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='Whats app']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='Whatsapp']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' WhatsApp']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Whatsaap']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Whatsapp ']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' wats up']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' whatsapp']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' whatsapp ']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' watsapp ']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='  whatsapp']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Whats app']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' whats app']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' whatapp']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' What\'s up']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' what\’s up ']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Watsapp']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' What\'s app']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Whatsup']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Whatsup ']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='whatspp']='WhatsApp'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' safari']='Safari'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Samsung pay']='SamsungPay'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='G mail']='GMail'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Gmail']='GMail'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' gmail']='GMail'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='gmail']='GMail'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Google Maps']='GMaps'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' google maps']='GMaps'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' gmaps']='GMaps'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' maps ']='GMaps'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='maps']='GMaps'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' expedia google maps']='GMaps'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Maps']='GMaps'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' LinkedIn']='LinkedIn'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Prime videos']='AmazonPrime'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='AmazonPrime ']='AmazonPrime'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Messenger']='FBMessenger'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' messenger']='FBMessenger'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' messanger']='FBMessenger'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='messanger ']='FBMessenger'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='FBMessenger ']='FBMessenger'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='  YouTube']='YouTube'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' YouTube']='YouTube'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' YouTube ']='YouTube'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Simple Radio']='Radio'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Waze']='Waze'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' photo']='Gallery'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Amazon']='Amazon'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='linkedin']='linkedIn'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' linkedin']='linkedIn'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' linkdin']='linkedIn'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Twitter']='Twitter'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' google duo']='Duo'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Viber']='Viber'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Splitwise']='Splitwise'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' traductor']='Traductor'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Chrome']='Chrome'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Flipboard']='Flipboard'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Yahoo mail ']='YMail'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Linio']='Linio'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' skype']='Skype'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='viber']='Viber'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Airbnb']='Airbnb'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Zomato']='Zomato'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Bank']='Bank'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Yummly']='Yummly'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' LINE']='LINE'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Candy crush']='CandyCrush'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' paytm ']='Paytm'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' rassegna stampa']='RassegnaStampa'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Sony Liv']='SonyLiv'
FinalDF['Top3App'].loc[FinalDF['Top3App']==' Robinhood']='Robinhood'
FinalDF['Top3App'].loc[FinalDF['Top3App']=='uc browser']='UCBrowser'

##################################################################################################


FinalDF['Top4App'].loc[FinalDF['Top4App']==' Instagram']='Instagram'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' istagram']='Instagram'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='instagram']='Instagram'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Instagram ']='Instagram'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' instagram']='Instagram'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' facebook']='Facebook'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='facebook']='Facebook'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' facebook ']='Facebook'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Facebook']='Facebook'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='  facebook']='Facebook'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Facebook ']='Facebook'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='facebook ']='Facebook'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='Whats app']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='Whatsapp']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' WhatsApp']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Whatsaap']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Whatsapp ']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' wats up']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' whatsapp']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' whatsapp ']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' watsapp ']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='  whatsapp']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Whats app']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' whats app']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' whatapp']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' What\'s up']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' what\’s up ']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Watsapp']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' What\'s app']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Whatsup']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Whatsup ']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='whatspp']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' WhatsApp ']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='whatts']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' safari']='Safari'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Safari']='Safari'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='safari']='Safari'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Samsung pay']='SamsungPay'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='G mail']='GMail'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Gmail']='GMail'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' gmail']='GMail'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='gmail']='GMail'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Google Maps']='GMaps'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' google maps']='GMaps'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' gmaps']='GMaps'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' maps ']='GMaps'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='maps']='GMaps'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' maps']='GMaps'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' expedia google maps']='GMaps'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Maps']='GMaps'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' LinkedIn']='LinkedIn'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Prime videos']='AmazonPrime'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='AmazonPrime ']='AmazonPrime'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Messenger']='FBMessenger'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' messenger']='FBMessenger'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' messanger']='FBMessenger'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='messanger ']='FBMessenger'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='FBMessenger ']='FBMessenger'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='  YouTube']='YouTube'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' YouTube']='YouTube'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' YouTube ']='YouTube'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' you tube']='YouTube'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='  youtube']='YouTube'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='youtube ']='YouTube'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='youtube']='YouTube'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' youtube']='YouTube' 
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Simple Radio']='Radio'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Waze']='Waze'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' photo']='Gallery'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Amazon']='Amazon'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='linkedin']='linkedIn'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' linkedin']='linkedIn'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' linkdin']='linkedIn'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Twitter']='Twitter'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' google duo']='Duo'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Viber']='Viber'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Splitwise']='Splitwise'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' traductor']='Traductor'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Chrome']='Chrome'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Flipboard']='Flipboard'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Yahoo mail ']='YMail'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Linio']='Linio'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' skype']='Skype'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='viber']='Viber'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Airbnb']='Airbnb'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Zomato']='Zomato'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Bank']='Bank'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Yummly']='Yummly'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' LINE']='LINE'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Candy crush']='CandyCrush'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' paytm ']='Paytm'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' rassegna stampa']='RassegnaStampa'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Sony Liv']='SonyLiv'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Robinhood']='Robinhood'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='uc browser']='UCBrowser'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='Whatsaap']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='Whatsapp ']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='wats up']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='whatsapp']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='watsapp ']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='Whats app']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='whats app']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='whatapp']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='What\'s up']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='Watsapp']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='What\'s app']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='Whatsup']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='Whatsup ']='WhatsApp'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='facebook']='Facebook'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='Facebook ']='Facebook'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='Fb']='Facebook'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='Messenger ']='FBMessenger'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='Messenger']='FBMessenger'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='Facebook Messenger']='FBMessenger'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='Google maps']='GMaps'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='Snap Chat']='SnapChat'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='Money control']='MoneyControl'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='Gmail']='GMail'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Spotify']='Spotify'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' spotify']='Spotify'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Note']='Note'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' DaviPlata']='DaviPlata'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' TOI']='TOI'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' weather']='Weather'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' hotmail']='Hotmail'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' fotos']='Gallery'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' paybyphone']='paybyphone'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Wynk Music']='WynkMusic'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Scoop']='Scoop'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' Bank account']='BankAccount'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' bank']='BankAccount'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' outlook']='Outlook'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' outlook ']='Outlook'
FinalDF['Top4App'].loc[FinalDF['Top4App']=='outlook']='Outlook'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' GoEuro']='GoEuro'
FinalDF['Top4App'].loc[FinalDF['Top4App']==' samsung music']='SamsungMusic'

#######################################################################################################################

FinalDF['Top5App'].loc[FinalDF['Top5App']==' Instagram']='Instagram'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' istagram']='Instagram'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='instagram']='Instagram'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Instagram ']='Instagram'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' instagram']='Instagram'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' facebook']='Facebook'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='facebook']='Facebook'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' facebook ']='Facebook'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Facebook']='Facebook'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='  facebook']='Facebook'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Facebook ']='Facebook'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='facebook ']='Facebook'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='Whats app']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='Whatsapp']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' WhatsApp']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Whatsaap']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Whatsapp ']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' wats up']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' whatsapp']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' whatsapp ']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' watsapp ']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='  whatsapp']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Whats app']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' whats app']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' whatapp']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' What\'s up']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' what\’s up ']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Watsapp']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' What\'s app']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Whatsup']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Whatsup ']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='whatspp']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' WhatsApp ']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='whatts']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' safari']='Safari'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Safari']='Safari'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='safari']='Safari'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Samsung pay']='SamsungPay'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='G mail']='GMail'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Gmail']='GMail'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' gmail']='GMail'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='gmail']='GMail'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Google Maps']='GMaps'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' google maps']='GMaps'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' gmaps']='GMaps'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' maps ']='GMaps'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='maps']='GMaps'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' maps']='GMaps'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' expedia google maps']='GMaps'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Maps']='GMaps'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' LinkedIn']='LinkedIn'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Prime videos']='AmazonPrime'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='AmazonPrime ']='AmazonPrime'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Messenger']='FBMessenger'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' messenger']='FBMessenger'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' messanger']='FBMessenger'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='messanger ']='FBMessenger'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='FBMessenger ']='FBMessenger'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='  YouTube']='YouTube'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' YouTube']='YouTube'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' YouTube ']='YouTube'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' you tube']='YouTube'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='  youtube']='YouTube'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='youtube ']='YouTube'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='youtube']='YouTube'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' youtube']='YouTube' 
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Simple Radio']='Radio'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Waze']='Waze'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' photo']='Gallery'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Amazon']='Amazon'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='linkedin']='linkedIn'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' linkedin']='linkedIn'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' linkdin']='linkedIn'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Twitter']='Twitter'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' google duo']='Duo'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Viber']='Viber'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Splitwise']='Splitwise'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' traductor']='Traductor'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Chrome']='Chrome'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Flipboard']='Flipboard'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Yahoo mail ']='YMail'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Linio']='Linio'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' skype']='Skype'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='viber']='Viber'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Airbnb']='Airbnb'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Zomato']='Zomato'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Bank']='Bank'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Yummly']='Yummly'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' LINE']='LINE'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Candy crush']='CandyCrush'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' paytm ']='Paytm'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' rassegna stampa']='RassegnaStampa'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Sony Liv']='SonyLiv'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Robinhood']='Robinhood'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='uc browser']='UCBrowser'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='Whatsaap']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='Whatsapp ']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='wats up']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='whatsapp']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='watsapp ']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='Whats app']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='whats app']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='whatapp']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='What\'s up']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='Watsapp']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='What\'s app']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='Whatsup']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='Whatsup ']='WhatsApp'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='facebook']='Facebook'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='Facebook ']='Facebook'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='Fb']='Facebook'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='Messenger ']='FBMessenger'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='Messenger']='FBMessenger'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='Facebook Messenger']='FBMessenger'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='Google maps']='GMaps'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='Snap Chat']='SnapChat'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='Money control']='MoneyControl'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='Gmail']='GMail'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Spotify']='Spotify'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' spotify']='Spotify'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Note']='Note'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' DaviPlata']='DaviPlata'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' TOI']='TOI'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' weather']='Weather'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' hotmail']='Hotmail'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' fotos']='Gallery'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' paybyphone']='paybyphone'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Wynk Music']='WynkMusic'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Scoop']='Scoop'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' Bank account']='BankAccount'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' bank']='BankAccount'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' outlook']='Outlook'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' outlook ']='Outlook'
FinalDF['Top5App'].loc[FinalDF['Top5App']=='outlook']='Outlook'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' GoEuro']='GoEuro'
FinalDF['Top5App'].loc[FinalDF['Top5App']==' samsung music']='SamsungMusic'

# %%
# English Cleaned!

# %%
FinalDF.to_csv('English_CleanedData_24_05_2018.csv',index=False)

# %%
df=pd.read_csv('SpanishData.csv')

# %%
del df['Timestamp']

# %%
df.head()
# Out:
#   1. Cuánto tiempo llevas usando un teléfono inteligente?  \
# 0                                   Entre 2 - 4 años
# 1                                   Entre 2 - 4 años
# 2                                      Más de 6 años
# 3                                      Más de 6 años
# 4                                                NaN
#
#   2. Qué marca de teléfono inteligente tienes?  \
# 0                                      Samsung
# 1                                       Xiaomi
# 2                                        Nokia
# 3                                      Samsung
# 4                                          NaN
#
#         3. Para qué usas principalmente tu teléfono?  \
# 0  Hacer llamadas;Tomar fotos;Redes Sociales;Escu...
# 1                                        Tomar fotos
# 2  Hacer llamadas;Tomar fotos;Enviar mensajes de ...
# 3                                     Redes Sociales
# 4                                                NaN
#
# ...

# %%
df=pd.read_csv('SpanishData.csv')
del df['Timestamp']
df.columns=['SmartPhoneUsagePeriod','SmartPhoneBrand','MainUsagePhone','UsagePeriod','ReasonForBuying','NumApps',
            'Top5Apps','DesiredFeature','PurchaseFrequency','Brand','Color','CameraQuality','BatteryLife','OS','Price',
            'ValueForMoney','Recom_Frnd_Fly','Trends','PromotionsAvailable','Call/Text','PrefMsgApp','PaymentGatewayUsage',
            'PriceRange','PhoneDistraction','Country','CountryLiveIn','Age']
#df=df.drop(df.index[0:8])
print("Shape of data:" + str(df.shape))
df.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-0d603692389e> in <module>()
#       4             'Top5Apps','DesiredFeature','PurchaseFrequency','Brand','Color','CameraQuality','BatteryLife','OS','Price',
#       5             'ValueForMoney','Recom_Frnd_Fly','Trends','PromotionsAvailable','Call/Text','PrefMsgApp','PaymentGatewayUsage',
# ----> 6             'PriceRange','PhoneDistraction','Country','CountryLiveIn','Age']
#       7 #df=df.drop(df.index[0:8])
#       8 print("Shape of data:" + str(df.shape))
#
# C:\Users\moham\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    2981         try:
#    2982             object.__getattribute__(self, name)
# -> 2983             return object.__setattr__(self, name, value)
#    2984         except AttributeError:
#    2985             pass
#
# ...
